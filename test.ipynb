# %%
import scipy.io
import numpy as np
import pandas as pd

# %%
mat_data = scipy.io.loadmat('wiki_test.mat')

wiki_data = mat_data['wiki'][0, 0]

data_dict = {
    'dob': wiki_data['dob'][0],
    'photo_taken': wiki_data['photo_taken'][0],
    'full_path': wiki_data['full_path'][0],
    'gender': wiki_data['gender'][0],
    'name': wiki_data['name'][0],
    'face_location': wiki_data['face_location'][0],
    'face_score': wiki_data['face_score'][0],
    'second_face_score': wiki_data['second_face_score'][0],
    'age': wiki_data['age'][0]
}

df = pd.DataFrame(data_dict)

df = df[['age', 'gender', 'full_path']]
df['full_path'] = df['full_path'].str[0]
df['full_path'] = 'wiki_crop/' + df['full_path']

df = df.dropna()

print(df)
# Out:
#        age  gender                                  full_path
# 0       28     1.0  wiki_crop/17/10000217_1981-05-05_2009.jpg
# 1       39     1.0  wiki_crop/48/10000548_1925-04-04_1964.jpg
# 2       59     1.0    wiki_crop/12/100012_1948-07-03_2008.jpg
# 3       31     1.0  wiki_crop/65/10001965_1930-05-23_1961.jpg
# 4       41     0.0  wiki_crop/16/10002116_1971-05-31_2012.jpg
# ...    ...     ...                                        ...
# 62323   26     1.0   wiki_crop/49/9996949_1937-04-17_1963.jpg
# 62324   22     1.0   wiki_crop/32/9997032_1947-07-30_1970.jpg
# 62325   40     1.0   wiki_crop/09/9998109_1972-12-27_2013.jpg
# 62326   29     1.0   wiki_crop/00/9999400_1981-12-13_2011.jpg
# 62327   54     0.0    wiki_crop/80/999980_1954-06-11_2008.jpg
#
# [59685 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, accuracy_score, mean_squared_error
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
from skimage.color import rgb2gray
from joblib import Parallel, delayed

# %%
# HOG feature extraction function
def extract_hog_features(path, target_size=(128, 128)):
    try:
        img = imread(path)
        img = resize(img, target_size, anti_aliasing=True)
        if len(img.shape) > 2:  # Convert to grayscale if RGB
            img = rgb2gray(img)
        # HOG parameters (optimized for speed)
        features = hog(img, 
                      orientations=8, 
                      pixels_per_cell=(16, 16),
                      cells_per_block=(1, 1), 
                      visualize=False,
                      channel_axis=None)
        return features
    except Exception as e:
        print(f"Error processing {path}: {str(e)}")
        return None

# Parallel feature extraction with HOG
print("Extracting HOG features in parallel...")
results = Parallel(n_jobs=-1, verbose=10)(
    delayed(extract_hog_features)(path) for path in df['full_path']
)

# Filter successful extractions
valid_features = []
valid_indices = []
for i, feat in enumerate(results):
    if feat is not None:
        valid_features.append(feat)
        valid_indices.append(i)

valid_df = df.iloc[valid_indices].copy()
x = np.array(valid_features)
y_age = valid_df['age'].values
y_gender = valid_df['gender'].values

# Train-test split
X_train, X_test, y_age_train, y_age_test, y_gender_train, y_gender_test = train_test_split(
    x, y_age, y_gender, test_size=0.2, random_state=42
)
# Out:
# Extracting HOG features in parallel...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1899181676102142s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.07477283477783203s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1591038703918457s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 520 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 688 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 872 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 1056 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 1256 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 1456 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done 1672 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done 1888 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 2120 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done 2352 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done 2600 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 2848 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 3112 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 3376 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 3656 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done 3936 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 4232 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 4528 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 4840 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 5152 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 5480 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 5808 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 6152 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done 6496 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 6856 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-1)]: Done 7216 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done 7592 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 7968 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-1)]: Done 8360 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done 8752 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 9160 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 9568 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done 9992 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done 10416 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done 10856 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done 11296 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 11752 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done 12208 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done 12680 tasks      | elapsed:   23.7s
# [Parallel(n_jobs=-1)]: Done 13152 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=-1)]: Done 13640 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=-1)]: Done 14128 tasks      | elapsed:   26.1s
# [Parallel(n_jobs=-1)]: Done 14632 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done 15136 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done 15656 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done 16176 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=-1)]: Done 16712 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 17248 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=-1)]: Done 17800 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done 18352 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 18920 tasks      | elapsed:   33.9s
# [Parallel(n_jobs=-1)]: Done 19488 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done 20072 tasks      | elapsed:   35.9s
# [Parallel(n_jobs=-1)]: Done 20656 tasks      | elapsed:   36.9s
# [Parallel(n_jobs=-1)]: Done 21256 tasks      | elapsed:   37.8s
# [Parallel(n_jobs=-1)]: Done 21856 tasks      | elapsed:   38.9s
# [Parallel(n_jobs=-1)]: Done 22472 tasks      | elapsed:   39.9s
# [Parallel(n_jobs=-1)]: Done 23088 tasks      | elapsed:   41.0s
# [Parallel(n_jobs=-1)]: Done 23720 tasks      | elapsed:   41.9s
# [Parallel(n_jobs=-1)]: Done 24352 tasks      | elapsed:   43.0s
# [Parallel(n_jobs=-1)]: Done 25000 tasks      | elapsed:   44.0s
# [Parallel(n_jobs=-1)]: Done 25648 tasks      | elapsed:   45.2s
# [Parallel(n_jobs=-1)]: Done 26312 tasks      | elapsed:   46.6s
# [Parallel(n_jobs=-1)]: Done 26976 tasks      | elapsed:   47.8s
# [Parallel(n_jobs=-1)]: Done 27656 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=-1)]: Done 28336 tasks      | elapsed:   50.5s
# [Parallel(n_jobs=-1)]: Done 29032 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=-1)]: Done 29728 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=-1)]: Done 30440 tasks      | elapsed:   55.0s
# [Parallel(n_jobs=-1)]: Done 31152 tasks      | elapsed:   56.2s
# [Parallel(n_jobs=-1)]: Done 31880 tasks      | elapsed:   57.6s
# [Parallel(n_jobs=-1)]: Done 32608 tasks      | elapsed:   59.0s
# [Parallel(n_jobs=-1)]: Done 33352 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 34096 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 34856 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 35616 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 36392 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 37168 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 37960 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 38752 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 39560 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 40368 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 41192 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 42016 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 42856 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 43696 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 44552 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 45408 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 46280 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 47152 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 48040 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 48928 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 49832 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 50736 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 51656 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 52576 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 53512 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 54448 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 55400 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 56352 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 57320 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 58288 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 59272 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 59685 out of 59685 | elapsed:  1.8min finished

# %%
from sklearn.neural_network import MLPRegressor, MLPClassifier
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier

# Age model
print("\nTraining age model...")
age_model = LinearRegression()
age_model.fit(X_train, y_age_train)
age_pred = age_model.predict(X_test)
print(f"Age MAE: {mean_absolute_error(y_age_test, age_pred):.2f} years")
print(f"Age RMSE: {mean_squared_error(y_age_test, age_pred)**0.5:.2f} years")

# KNN for Age
age_knn = KNeighborsRegressor(n_neighbors=5)
age_knn.fit(X_train, y_age_train)
age_knn_pred = age_knn.predict(X_test)
print(f"KNN Age MAE: {mean_absolute_error(y_age_test, age_knn_pred):.2f} years")
print(f"KNN Age RMSE: {mean_squared_error(y_age_test, age_knn_pred)**0.5:.2f} years")

# MLP for Age
age_mlp = MLPRegressor(hidden_layer_sizes=(64, 32), 
                      activation='relu', 
                      solver='adam', 
                      max_iter=100, 
                      random_state=42)
age_mlp.fit(X_train, y_age_train)
age_mlp_pred = age_mlp.predict(X_test)
print(f"MLP Age MAE: {mean_absolute_error(y_age_test, age_mlp_pred):.2f} years")
print(f"MLP Age RMSE: {mean_squared_error(y_age_test, age_mlp_pred)**0.5:.2f} years")

# Gender model
print("\nTraining gender model...")
gender_model = LogisticRegression(max_iter=1000)
gender_model.fit(X_train, y_gender_train)
gender_pred = gender_model.predict(X_test)
print(f"Gender accuracy: {accuracy_score(y_gender_test, gender_pred):.2f}")

# KNN for Gender
gender_knn = KNeighborsClassifier(n_neighbors=5)
gender_knn.fit(X_train, y_gender_train)
gender_knn_pred = gender_knn.predict(X_test)
print(f"KNN Gender accuracy: {accuracy_score(y_gender_test, gender_knn_pred):.2f}")

# MLP for Gender
gender_mlp = MLPClassifier(hidden_layer_sizes=(64, 32), 
                          activation='relu', 
                          solver='adam', 
                          max_iter=100, 
                          random_state=42)
gender_mlp.fit(X_train, y_gender_train)
gender_mlp_pred = gender_mlp.predict(X_test)
print(f"MLP Gender accuracy: {accuracy_score(y_gender_test, gender_mlp_pred):.2f}")
# Out:
# Training age model...
# Age MAE: 13.65 years
# Age RMSE: 23.28 years
# KNN Age MAE: 15.33 years
# KNN Age RMSE: 25.27 years
# c:\Users\danie\OneDrive\Desktop\last\334\venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP Age MAE: 13.02 years
# MLP Age RMSE: 23.11 years
#
# Training gender model...
# Gender accuracy: 0.85
# KNN Gender accuracy: 0.82
# MLP Gender accuracy: 0.84
# c:\Users\danie\OneDrive\Desktop\last\334\venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
